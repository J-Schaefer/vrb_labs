# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.experiment_tracy import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 if module_path not in sys.path:
#       5     sys.path.append(module_path)
# ----> 7 from src.experiment_tracy import *
#
# File ~/Documents/vrb_labs/src/experiment_tracy.py:12
#       9 from copy import deepcopy
#      11 # ROS Imports
# ---> 12 import rospy
#      13 from visualization_msgs.msg import Marker
#      14 from geometry_msgs.msg import PoseStamped, Quaternion, Point
#
# ModuleNotFoundError: No module named 'rospy'
