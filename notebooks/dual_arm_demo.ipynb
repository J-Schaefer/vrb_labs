# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

from experiment_tracy import *

# %%
# Run the first experiment without the heuristic
run_experiment_tracy(dual_heuristic=False)

# %%
# Run the first experiment using the heuristic
run_experiment_tracy(dual_heuristic=True)

# %%
# Run the second experiment without the heuristic
run_experiment_random(dual_heuristic=False)

# %%
# Run the second experiment using the heuristic
run_experiment_random(dual_heuristic=True)
